# %% [markdown]
# # **Anaemia Detection**

# %% [markdown]
# ##  **Importing Necessary Libraries**

# %%
import numpy as np
import pandas as pd 
# %matplotlib widget
impotensorflow.keras.modelsrt tensorflow as tf
from  import Sequential
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split,StratifiedShuffleSplit
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay,accuracy_score,classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
import seaborn as sb
import plotly.figure_factory as px
import pickle
from sklearn.linear_model import LogisticRegression

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# ## **Loading The Dataset**

# %%
df = pd.read_csv("anemia.csv")
df
# Out:
#       Gender  Hemoglobin   MCH  MCHC   MCV  Result
# 0          1        14.9  22.7  29.1  83.7       0
# 1          0        15.9  25.4  28.3  72.0       0
# 2          0         9.0  21.5  29.6  71.2       1
# 3          0        14.9  16.0  31.4  87.5       0
# 4          1        14.7  22.0  28.2  99.5       0
# ...      ...         ...   ...   ...   ...     ...
# 1416       0        10.6  25.4  28.2  82.9       1
# 1417       1        12.1  28.3  30.4  86.9       1
# 1418       1        13.1  17.7  28.1  80.7       1
# 1419       0        14.3  16.2  29.5  95.2       0
# 1420       0        11.8  21.2  28.4  98.1       1
#
# [1421 rows x 6 columns]

# %%
df_pos  =df[df["Result"]==0]
df_pos = df_pos.head(181)
df.drop(df_pos.index,inplace = True)

# %%
df.reset_index(inplace = True)

# %%
df.drop(['index'],axis =1,inplace=True)
df
# Out:
#       Gender  Hemoglobin   MCH  MCHC   MCV  Result
# 0          0         9.0  21.5  29.6  71.2       1
# 1          0        11.6  22.3  30.9  74.5       1
# 2          1        12.7  19.5  28.9  82.9       1
# 3          1        12.7  28.5  28.2  92.3       1
# 4          1        13.0  18.3  29.6  87.8       1
# ...      ...         ...   ...   ...   ...     ...
# 1235       0        10.6  25.4  28.2  82.9       1
# 1236       1        12.1  28.3  30.4  86.9       1
# 1237       1        13.1  17.7  28.1  80.7       1
# 1238       0        14.3  16.2  29.5  95.2       0
# 1239       0        11.8  21.2  28.4  98.1       1
#
# [1240 rows x 6 columns]

# %%
x = np.array(df.drop("Result",axis = 1))
y = np.array(df["Result"])
y_df = pd.DataFrame(df['Result'])

# %%
split =StratifiedShuffleSplit(n_splits=1,test_size=0.2,random_state=9)

for train_index,test_index in split.split(df,df['Result']):
    strat_train_set = df.loc[train_index]
    strat_test_set = df.loc[test_index]

# %%
a = strat_train_set['Result'].value_counts()
print(f"Training Samples : {len(strat_train_set)}")
print(f"Train ratio = 1 : {a[0]/a[1]}")
# Out:
# Training Samples : 992
# Train ratio = 1 : 1.0

# %%
b = strat_test_set['Result'].value_counts()
print(f"Testing Samples : {len(strat_test_set)}")
print(f"Test ratio = 1  : {b[0]/b[1]}")
# Out:
# Testing Samples : 248
# Test ratio = 1  : 1.0

# %%
x_train = np.array(strat_train_set.drop('Result',axis=1))
y_train = np.array(strat_train_set['Result'])
x_tst = np.array(strat_test_set.drop('Result',axis =1))
y_tst = np.array(strat_test_set['Result'])

# %%
print(f'''x_train Shape : {x_train.shape}
x_test Shape : {x_tst.shape}

''')
# Out:
# x_train Shape : (992, 5)
# x_test Shape : (248, 5)

# %% [markdown]
# ## **Modelling**

# %%
model = Sequential([
    Dense(128,activation = 'relu',kernel_regularizer=tf.keras.regularizers.l2(0.1)),
    Dense(40,activation = 'relu',kernel_regularizer= tf.keras.regularizers.l2(0.1)),
    Dense(1,activation= 'linear')
])

# %%
model.compile(loss = tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer=  tf.keras.optimizers.Adam(learning_rate = 0.01),
               
             metrics = ["accuracy"])

# %% [markdown]
# **Model For Train Set**

# %%
hist_train = model.fit(x_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 31/31 [==============================] - 3s 4ms/step - loss: 3.8173 - accuracy: 0.5161
# Epoch 2/100
# 31/31 [==============================] - 0s 4ms/step - loss: 1.7161 - accuracy: 0.5806
# Epoch 3/100
# 31/31 [==============================] - 0s 4ms/step - loss: 1.2994 - accuracy: 0.5927
# Epoch 4/100
# 31/31 [==============================] - 0s 3ms/step - loss: 1.1047 - accuracy: 0.6129
# Epoch 5/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.9058 - accuracy: 0.6522
# Epoch 6/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.8015 - accuracy: 0.6381
# Epoch 7/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.7476 - accuracy: 0.7147
# Epoch 8/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.8395 - accuracy: 0.6462
# Epoch 9/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.8033 - accuracy: 0.5181
# Epoch 10/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.6924 - accuracy: 0.6079
# Epoch 11/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.6873 - accuracy: 0.6694
# Epoch 12/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.6636 - accuracy: 0.6784
# Epoch 13/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.5936 - accuracy: 0.7621
# Epoch 14/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.5708 - accuracy: 0.7742
# Epoch 15/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5414 - accuracy: 0.8196
# Epoch 16/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5040 - accuracy: 0.8367
# Epoch 17/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5623 - accuracy: 0.7722
# Epoch 18/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5630 - accuracy: 0.7762
# Epoch 19/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.4585 - accuracy: 0.8649
# Epoch 20/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4613 - accuracy: 0.8629
# Epoch 21/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4499 - accuracy: 0.8710
# Epoch 22/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4455 - accuracy: 0.8599
# Epoch 23/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4286 - accuracy: 0.8629
# Epoch 24/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4021 - accuracy: 0.8810
# Epoch 25/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5349 - accuracy: 0.7974
# Epoch 26/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4129 - accuracy: 0.8750
# Epoch 27/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4503 - accuracy: 0.8438
# Epoch 28/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4399 - accuracy: 0.8508
# Epoch 29/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4332 - accuracy: 0.8659
# Epoch 30/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4582 - accuracy: 0.8357
# Epoch 31/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4317 - accuracy: 0.8548
# Epoch 32/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3883 - accuracy: 0.8810
# Epoch 33/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3815 - accuracy: 0.8800
# Epoch 34/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3699 - accuracy: 0.8942
# Epoch 35/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3672 - accuracy: 0.8921
# Epoch 36/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3695 - accuracy: 0.8881
# Epoch 37/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3697 - accuracy: 0.8911
# Epoch 38/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4137 - accuracy: 0.8700
# Epoch 39/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3959 - accuracy: 0.8669
# Epoch 40/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3733 - accuracy: 0.8659
# Epoch 41/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.3445 - accuracy: 0.8982
# Epoch 42/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.3868 - accuracy: 0.8821
# Epoch 43/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4284 - accuracy: 0.8387
# Epoch 44/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3650 - accuracy: 0.8780
# Epoch 45/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3487 - accuracy: 0.8901
# Epoch 46/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3715 - accuracy: 0.8911
# Epoch 47/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.3456 - accuracy: 0.8871
# Epoch 48/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3314 - accuracy: 0.9022
# Epoch 49/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3638 - accuracy: 0.8871
# Epoch 50/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.3667 - accuracy: 0.8790
# Epoch 51/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3283 - accuracy: 0.9002
# Epoch 52/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.3055 - accuracy: 0.9133
# Epoch 53/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3078 - accuracy: 0.9173
# Epoch 54/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.3034 - accuracy: 0.9083
# Epoch 55/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3184 - accuracy: 0.9012
# Epoch 56/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3684 - accuracy: 0.8760
# Epoch 57/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3394 - accuracy: 0.8851
# Epoch 58/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3112 - accuracy: 0.9103
# Epoch 59/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3099 - accuracy: 0.9143
# Epoch 60/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3116 - accuracy: 0.9113
# Epoch 61/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3392 - accuracy: 0.8861
# Epoch 62/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3338 - accuracy: 0.8942
# Epoch 63/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3167 - accuracy: 0.9032
# Epoch 64/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.2982 - accuracy: 0.9163
# Epoch 65/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3451 - accuracy: 0.8921
# Epoch 66/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3294 - accuracy: 0.8891
# Epoch 67/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3517 - accuracy: 0.8800
# Epoch 68/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3026 - accuracy: 0.9103
# Epoch 69/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.3207 - accuracy: 0.8921
# Epoch 70/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2995 - accuracy: 0.9133
# Epoch 71/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3178 - accuracy: 0.9012
# Epoch 72/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.2799 - accuracy: 0.9194
# Epoch 73/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2830 - accuracy: 0.9204
# Epoch 74/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2763 - accuracy: 0.9234
# Epoch 75/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2969 - accuracy: 0.9103
# Epoch 76/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3169 - accuracy: 0.9123
# Epoch 77/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2742 - accuracy: 0.9234
# Epoch 78/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3260 - accuracy: 0.8800
# Epoch 79/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2935 - accuracy: 0.9103
# Epoch 80/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3317 - accuracy: 0.8831
# Epoch 81/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2781 - accuracy: 0.9224
# Epoch 82/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2722 - accuracy: 0.9234
# Epoch 83/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2811 - accuracy: 0.9123
# Epoch 84/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2657 - accuracy: 0.9325
# Epoch 85/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3368 - accuracy: 0.8780
# Epoch 86/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2657 - accuracy: 0.9294
# Epoch 87/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2705 - accuracy: 0.9244
# Epoch 88/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2663 - accuracy: 0.9224
# Epoch 89/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3020 - accuracy: 0.9052
# Epoch 90/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2930 - accuracy: 0.9002
# Epoch 91/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2962 - accuracy: 0.9103
# Epoch 92/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2657 - accuracy: 0.9315
# Epoch 93/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2584 - accuracy: 0.9325
# Epoch 94/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2733 - accuracy: 0.9214
# Epoch 95/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2909 - accuracy: 0.9113
# Epoch 96/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2568 - accuracy: 0.9264
# Epoch 97/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2529 - accuracy: 0.9315
# Epoch 98/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2675 - accuracy: 0.9194
# Epoch 99/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2617 - accuracy: 0.9214
# Epoch 100/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2682 - accuracy: 0.9254

# %% [markdown]
# **Model for Test Set**

# %%
hist_tst = model.fit(x_tst,y_tst,epochs=100)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 1s 3ms/step - loss: 0.2968 - accuracy: 0.8952
# Epoch 2/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3097 - accuracy: 0.8831
# Epoch 3/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3085 - accuracy: 0.8911
# Epoch 4/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3071 - accuracy: 0.9032
# Epoch 5/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2680 - accuracy: 0.9234
# Epoch 6/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2582 - accuracy: 0.9355
# Epoch 7/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2552 - accuracy: 0.9355
# Epoch 8/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2641 - accuracy: 0.9395
# Epoch 9/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3140 - accuracy: 0.9073
# Epoch 10/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2533 - accuracy: 0.9435
# Epoch 11/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2733 - accuracy: 0.9355
# Epoch 12/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3444 - accuracy: 0.8871
# Epoch 13/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3331 - accuracy: 0.8831
# Epoch 14/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2916 - accuracy: 0.9113
# Epoch 15/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2541 - accuracy: 0.9435
# Epoch 16/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2646 - accuracy: 0.9234
# Epoch 17/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2711 - accuracy: 0.9113
# Epoch 18/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2890 - accuracy: 0.9355
# Epoch 19/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2756 - accuracy: 0.9234
# Epoch 20/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2428 - accuracy: 0.9435
# Epoch 21/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2921 - accuracy: 0.9274
# Epoch 22/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3192 - accuracy: 0.8952
# Epoch 23/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2769 - accuracy: 0.9315
# Epoch 24/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2475 - accuracy: 0.9516
# Epoch 25/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2585 - accuracy: 0.9315
# Epoch 26/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2510 - accuracy: 0.9274
# Epoch 27/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2446 - accuracy: 0.9315
# Epoch 28/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3038 - accuracy: 0.8911
# Epoch 29/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3417 - accuracy: 0.8629
# Epoch 30/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2553 - accuracy: 0.9435
# Epoch 31/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2877 - accuracy: 0.9315
# Epoch 32/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2728 - accuracy: 0.9073
# Epoch 33/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2554 - accuracy: 0.9637
# Epoch 34/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2504 - accuracy: 0.9516
# Epoch 35/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2573 - accuracy: 0.9395
# Epoch 36/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2423 - accuracy: 0.9476
# Epoch 37/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2691 - accuracy: 0.9032
# Epoch 38/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3132 - accuracy: 0.8952
# Epoch 39/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3144 - accuracy: 0.8911
# Epoch 40/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3965 - accuracy: 0.8669
# Epoch 41/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3548 - accuracy: 0.8589
# Epoch 42/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2614 - accuracy: 0.9194
# Epoch 43/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2458 - accuracy: 0.9476
# Epoch 44/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2555 - accuracy: 0.9315
# Epoch 45/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2495 - accuracy: 0.9476
# Epoch 46/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3003 - accuracy: 0.9153
# Epoch 47/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3093 - accuracy: 0.8952
# Epoch 48/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2494 - accuracy: 0.9476
# Epoch 49/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2563 - accuracy: 0.9556
# Epoch 50/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2609 - accuracy: 0.9435
# Epoch 51/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2727 - accuracy: 0.9194
# Epoch 52/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2377 - accuracy: 0.9597
# Epoch 53/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2465 - accuracy: 0.9556
# Epoch 54/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2780 - accuracy: 0.9234
# Epoch 55/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2738 - accuracy: 0.9032
# Epoch 56/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3190 - accuracy: 0.8871
# Epoch 57/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2907 - accuracy: 0.9073
# Epoch 58/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3370 - accuracy: 0.8629
# Epoch 59/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3260 - accuracy: 0.8669
# Epoch 60/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2745 - accuracy: 0.9355
# Epoch 61/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2433 - accuracy: 0.9516
# Epoch 62/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2528 - accuracy: 0.9355
# Epoch 63/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2615 - accuracy: 0.9194
# Epoch 64/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3088 - accuracy: 0.8831
# Epoch 65/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3014 - accuracy: 0.9073
# Epoch 66/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2898 - accuracy: 0.8911
# Epoch 67/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2867 - accuracy: 0.8952
# Epoch 68/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2442 - accuracy: 0.9435
# Epoch 69/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2366 - accuracy: 0.9435
# Epoch 70/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2346 - accuracy: 0.9516
# Epoch 71/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2445 - accuracy: 0.9355
# Epoch 72/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2732 - accuracy: 0.9113
# Epoch 73/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2515 - accuracy: 0.9355
# Epoch 74/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2577 - accuracy: 0.9234
# Epoch 75/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2328 - accuracy: 0.9637
# Epoch 76/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2394 - accuracy: 0.9435
# Epoch 77/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2410 - accuracy: 0.9556
# Epoch 78/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2529 - accuracy: 0.9274
# Epoch 79/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2352 - accuracy: 0.9597
# Epoch 80/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2724 - accuracy: 0.9234
# Epoch 81/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2762 - accuracy: 0.9032
# Epoch 82/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3620 - accuracy: 0.8589
# Epoch 83/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3774 - accuracy: 0.8387
# Epoch 84/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3628 - accuracy: 0.8750
# Epoch 85/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2861 - accuracy: 0.8871
# Epoch 86/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2820 - accuracy: 0.9153
# Epoch 87/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2587 - accuracy: 0.9274
# Epoch 88/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2614 - accuracy: 0.9355
# Epoch 89/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2387 - accuracy: 0.9516
# Epoch 90/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2403 - accuracy: 0.9476
# Epoch 91/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2374 - accuracy: 0.9476
# Epoch 92/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2371 - accuracy: 0.9597
# Epoch 93/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2446 - accuracy: 0.9315
# Epoch 94/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2393 - accuracy: 0.9476
# Epoch 95/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2489 - accuracy: 0.9435
# Epoch 96/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2435 - accuracy: 0.9355
# Epoch 97/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2671 - accuracy: 0.9153
# Epoch 98/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2510 - accuracy: 0.9355
# Epoch 99/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2488 - accuracy: 0.9234
# Epoch 100/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2561 - accuracy: 0.9355

# %% [markdown]
# ### Detail about the accuracy and loss of the model

# %%
hist_m2_tr = pd.DataFrame(hist_train.history)
hist_m2_tr.rename(columns={'loss':'train loss','accuracy' : "train acc"},inplace=True)
hist_m2_ts = pd.DataFrame(hist_tst.history)
hist_m2_ts.rename(columns={'loss':'test loss',"accuracy":"test acc"},inplace = True)
con = [hist_m2_ts,hist_m2_tr]

comb2 = pd.concat(con,axis=1,join="inner")
comb2
# Out:
#     test loss  test acc  train loss  train acc
# 0    0.296763  0.895161    3.817345   0.516129
# 1    0.309702  0.883065    1.716120   0.580645
# 2    0.308521  0.891129    1.299352   0.592742
# 3    0.307110  0.903226    1.104727   0.612903
# 4    0.267971  0.923387    0.905808   0.652218
# ..        ...       ...         ...        ...
# 95   0.243501  0.935484    0.256754   0.926411
# 96   0.267133  0.915323    0.252930   0.931452
# 97   0.251009  0.935484    0.267487   0.919355
# 98   0.248755  0.923387    0.261745   0.921371
# 99   0.256076  0.935484    0.268161   0.925403
#
# [100 rows x 4 columns]

# %%
fig,ax = plt.subplots(1,1)
ax.plot(np.arange(100),comb2['train loss'],label = 'Train Loss')
ax.plot(np.arange(100),comb2['test loss'],label = 'Test Loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Epoch VS Loss")
plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               768
#
#  dense_1 (Dense)             (None, 40)                5160
#
#  dense_2 (Dense)             (None, 1)                 41
#
# =================================================================
# Total params: 5,969
# Trainable params: 5,969
# Non-trainable params: 0
# _________________________________________________________________

# %%
def my_predict(x,pos=None):
    
    p2 = model.predict(x)
    pr2 = tf.nn.sigmoid(p2)
    a2 = np.zeros(len(pr2))
    for i in range(len(pr2)):
        if pr2[i]>0.5:
            a2[i] = np.array(pr2[i])
            a2[i] =  1
        else :
            a2[i] = np.array(pr2[i])
            a2[i]  = 0

    
    return a2

# %% [markdown]
# ## **Checking Model Prediction By Confusion Matrix**

# %%
prd_train = my_predict(x_train)
cd = confusion_matrix(y_train,prd_train)
# Out:
# 31/31 [==============================] - 0s 2ms/step

# %%
cm_display = ConfusionMatrixDisplay(cd)

# %%
cm_display.plot()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print(classification_report(y_train,prd_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.93      0.96       496
#            1       0.93      1.00      0.96       496
#
#     accuracy                           0.96       992
#    macro avg       0.96      0.96      0.96       992
# weighted avg       0.96      0.96      0.96       992

# %%
pre = cd[0,0]/(cd[0,0]+cd[0,1])
rec = cd[0,0]/(cd[0,0]+cd[1,0])
f1 = 2*pre*rec/(pre+rec)

# %%
print(f'''Precision : {pre}
Recall : {rec:.2f}
F1 Score : {f1:.2f}''')
# Out:
# Precision : 0.9274193548387096
# Recall : 1.00
# F1 Score : 0.96

# %%
prd_tst1 = my_predict(x_tst)
# Out:
# 8/8 [==============================] - 0s 2ms/step

# %%
print(f" Model1 Accuracy : {accuracy_score(y_train,prd_train)}")
print(f" Model2 Accuracy : {accuracy_score(y_tst,prd_tst1)}")
# Out:
#  Model1 Accuracy : 0.9616935483870968
#  Model2 Accuracy : 0.9435483870967742

# %%
imp1 = np.array([[0,11.9,28.3,31.9,88.8]])

my_predict(imp1)
# Out:
# 1/1 [==============================] - 0s 35ms/step
# array([1.])

# %%
imp2 = np.array([[1,13.5,26.9,32.6,82.6]])

my_predict(imp2)
# Out:
# 1/1 [==============================] - 0s 41ms/step
# array([1.])

# %% [markdown]
# ## **Checking Model Prediction by Logistic Regression**

# %%
logr = LogisticRegression()

# %%
logr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
prd_logr = logr.predict(x_train)
prd_tst = logr.predict(x_tst)

# %%
cm_log = confusion_matrix(y_train,prd_logr)

# %%
cm_d = ConfusionMatrixDisplay(cm_log)
cm_d.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pre_lg = cm_log[0,0]/(cm_log[0,0]+cm_log[0,1])
rec_lg = cm_log[0,0]/(cm_log[0,0]+cm_log[1,0])
f11_lg = 2*pre_lg*rec_lg/(pre_lg+rec_lg)




print(f'''Precision : {pre_lg}
Recall : {rec_lg:.2f}
F1 Score : {f11_lg:.2f}''')
# Out:
# Precision : 0.9717741935483871
# Recall : 1.00
# F1 Score : 0.99

# %%
cm_log
# Out:
# array([[482,  14],
#        [  0, 496]], dtype=int64)

# %%
print(classification_report(y_train,prd_logr))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99       496
#            1       0.97      1.00      0.99       496
#
#     accuracy                           0.99       992
#    macro avg       0.99      0.99      0.99       992
# weighted avg       0.99      0.99      0.99       992

# %%
print(classification_report(y_tst,prd_tst))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98       124
#            1       0.96      1.00      0.98       124
#
#     accuracy                           0.98       248
#    macro avg       0.98      0.98      0.98       248
# weighted avg       0.98      0.98      0.98       248

# %%
logr.predict(imp1)
# Out:
# array([1], dtype=int64)

# %%
logr.predict(imp2)
# Out:
# array([1], dtype=int64)

# %% [markdown]
# ## **Train with Decision Tree**

# %%
tree_cf = DecisionTreeClassifier()
tree_cf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
prd_tree = tree_cf.predict(x_train)
prd_tst_tree = tree_cf.predict(x_tst)

# %%
cm_t = confusion_matrix(y_train,prd_tree)
cm_d = ConfusionMatrixDisplay(cm_t)
cm_d.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
cm_tt = confusion_matrix(y_tst,prd_tst_tree)
cm_d = ConfusionMatrixDisplay(cm_tt)
cm_d.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print(classification_report(y_train,prd_tree))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       496
#            1       1.00      1.00      1.00       496
#
#     accuracy                           1.00       992
#    macro avg       1.00      1.00      1.00       992
# weighted avg       1.00      1.00      1.00       992

# %%
np.mean(cross_val_score(tree_cf,x_train,y_train,cv =10))
# Out:
# 1.0

# %%
tree_cf.predict(imp1)
# Out:
# array([1], dtype=int64)

# %%
tree_cf.predict(imp2)
# Out:
# array([0], dtype=int64)

# %%
sb.displot(df[df['Result'] == 1]['Hemoglobin'],kde = True)
sb.displot(df[df['Result'] == 0]['Hemoglobin'],kde = True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
a =list((df[df['Result'] == 1]['Hemoglobin']))
b =list((df[df['Result'] == 0]['Hemoglobin']))
c = [a,b]

px.create_distplot(hist_data=c,group_labels=['True','False'],show_rug=False,colors=['Red','Green'])

# %%
a =list((df[df['Result'] == 1]['MCH']))
b =list((df[df['Result'] == 0]['MCH']))
c = [a,b]

px.create_distplot(hist_data=c,group_labels=['True','False'],show_rug=False,colors=['Red','Green'])

# %%
a =list((df[df['Result'] == 1]['MCV']))
b =list((df[df['Result'] == 0]['MCV']))

c = [a,b]

px.create_distplot(hist_data=c,group_labels=['True','False'],show_rug=False,colors=['red','lightgreen'])

# %% [markdown]
# ## **Pickling the file**

# %%
import pickle

# %%
with open('anemia_detection', 'wb') as files:
    pickle.dump(tree_cf, files)

# %%
with open('anemia_detection' , 'rb') as f:
    lr = pickle.load(f)
